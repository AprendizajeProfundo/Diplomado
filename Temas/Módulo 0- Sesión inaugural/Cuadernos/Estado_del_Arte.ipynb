# %% [markdown]
# <img src="../Imagenes/logo_final.png" alt="AP Logo">

# %% [markdown]
# # <span style="color:red"><center>Inteligencia Artificial</center></span>

# %% [markdown]
# <center>Estado del Arte y claves de su desarrollo</center>

# %% [markdown]
# <br></br>
# <br></br>
#
# **<center> Álvaro Mauricio Montenegro Díaz, PhD , <a href="">ammontenegrod@unal.edu.co</a></center>**
#
# **<center>Daniel Mauricio Montenegro Reyes, MSc, <a href="">info@aprendizajeprofundo.co</a></center>**

# %% [markdown]
# ## Concepto

# %% [markdown]
# [**¿Qué es la inteligencia artificial?**](https://youtu.be/IEBMi_LuFzE)
#
# [**¿Es verdad lo que dicen en las noticias sobre IA?**](https://youtu.be/PbS9h1scD6Q)
#
# [**¿Puede una máquina pensar?**](https://youtu.be/cTAaSXagCaU?t=341)
#
#
# <a href="https://www.forbes.com/real-time-billionaires"><b>¿Es el fin de la humanidad?</b></a>

# %% [markdown]
# ## Redes Convolucionales $\to$ Reconocimiento Facial

# %% [markdown]
# <div id="images">
#     <img src="../Imagenes/Dani1.jpg" alt="asd" style="width:300px;height:300px;">
#     <img src="../Imagenes/arrow.png" alt="asd2" style="width:200px;height:300px;">
#     <img src="../Imagenes/Dani7.jpg" alt="asda2" style="width:250px;height:300px;">
# </div>

# %% [markdown]
# ## Segmentación de Imágenes

# %% [markdown]
# - Conducción Automática
#
# <center>
# <img src="https://github.com/facebookresearch/Detectron/blob/main/demo/output/33823288584_1d21cf0a26_k_example_output.jpg?raw=true" alt="asd" style="width:800px;height:500px;">
# </center>

# %% [markdown]
# ## Redes Recurrentes $\to$ Predicción en la Bolsa

# %% [markdown]
# <center><img src="../Imagenes/Apple_prediction.png" alt="asd" style="width:900px;height:500px;"></center>

# %% [markdown]
# ### Transformers $\to$ GPT-3
#
# Más, chatbots... Pero esta vez...**¿Saben programar?**
#
# [![Neuralink](../Imagenes/gpt3.jpg)](https://www.xataka.com/robotica-e-ia/gpt-3-nuevo-modelo-lenguaje-openai-capaz-programar-disenar-conversar-politica-economia)
#
# [Pide Acceso](https://beta.openai.com/?demo=5)
#
# Fuente: [Xataka](https://www.xataka.com/robotica-e-ia/gpt-3-nuevo-modelo-lenguaje-openai-capaz-programar-disenar-conversar-politica-economia)

# %% [markdown]
# ### Ejemplo

# %% [markdown]
# <center>
# <iframe width="853" height="480" src="https://www.youtube.com/embed/uCpE6z999Uk" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# </center>

# %% [markdown]
# ## Hugging Face: Acercando la IA a las personas

# %% [markdown]
# - [¿Qué puede hacer un Transformer?](https://colab.research.google.com/github/huggingface/notebooks/blob/master/course/chapter1/section3.ipynb)
#
# <center><img src="https://huggingface.co/front/assets/huggingface_logo.svg" alt="DALL-E" style="width:650px;height:400px;"></center>

# %% [markdown]
# ### Transformers $\to $DALL-E

# %% [markdown]
# ¿Adiós a los diseñadores gráficos?
#
# <center><img src="https://daleonai.com/images/screen-shot-2021-01-06-at-1.39.12-pm.png" alt="DALL-E" style="width:650px;height:400px;"></center>
#
# **Un caracol hecho de Arpa.**
#
# Fuente de la imagen: [Dale on AI](https://daleonai.com/dalle-5-mins)
#
# [[Pequeña Explicación]](https://youtu.be/ztvtcKDrSwM) [[Interacción]](https://openai.com/blog/dall-e/)

# %% [markdown]
# ## Interacción

# %% [markdown]
# <embed src="https://openai.com/blog/dall-e/" style="width:800px; height: 600px;">

# %% [markdown]
# ### Autoencoders Variacionales + Transformers $\to$ Jukebox

# %% [markdown]
# ¿Generación de canciones automáticas?

# %% [markdown]
# <audio controls>
#     <source src="../Audios/test.mp3" type="audio/mpeg">
# </audio>

# %% [markdown]
# [![Jukebox](https://cdn.computerhoy.com/sites/navi.axelspringer.es/public/styles/480/public/media/image/2020/05/inteligencia-artificial-openai-ya-compone-canciones-suenan-como-sinatra-katy-perry-elvis-presley-1933931.jpg?itok=bdb8nbls)](https://openai.com/blog/jukebox/)
#
# Fuente:  [Computer Hoy](https://cdn.computerhoy.com/sites/navi.axelspringer.es/public/styles/1200/public/media/image/2020/05/inteligencia-artificial-openai-ya-compone-canciones-suenan-como-sinatra-katy-perry-elvis-presley-1933931.jpg?itok=oE8ErHL4)

# %% [markdown]
# ### GANS (Redes Generativas) $\to$ Personas

# %% [markdown]
# **¿Qué tienen en común TODAS las siguientes personas?**
#
# ![Fake Faces](https://miro.medium.com/max/700/1*Tfm4R3OS9GmXdOvR_mmDKw.png)
#
# Fuente: ["..People, Cars, and Cats"](https://towardsdatascience.com/using-artificial-intelligence-to-create-people-cars-and-cats-5117189d0625)
#
#
#
# **Modelos Generativos (Ejemplo de OpenAI):** [Glow: Better Reversible Generative Models](https://openai.com/blog/glow/)

# %% [markdown]
# # ¿Asustado? ¡Hay más!

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('cQ54GDm1eL0', width=800, height=400)

# %% [markdown]
# **Juego:** [Ser o no ser](https://www.whichfaceisreal.com/)

# %% [markdown]
# Noticia: [El comercio](https://www.elcomercio.com/afull/barackobama-fakenews-buzzfeed-inteligenciaartificial-viral.html)

# %% [markdown]
# ## Mezcla de Tecnologías $\to$ Entrevistas con personas del más allá

# %% [markdown]
#  - GPT-3
#  - Speaker encoder network
#  - Sequence-to-sequence
#  - Auto-regressive WaveNet-based vocoder network
#
# <center>
# <iframe width="853" height="400" src="https://www.youtube.com/embed/LzE2pJbuYRk" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# </center>

# %% [markdown]
# ## Mezcla de Tecnologías $\to$ AI vs AI

# %% [markdown]
# <center>
# <iframe width="853" height="480" src="https://www.youtube.com/embed/jz78fSnBG0s" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# </center>

# %% [markdown]
# ##  Aprendizaje Reforzado $\to$ Hide and Seek

# %% [markdown]
# ¡Juguemos a las escondidas!
#
# [![Hide and Seek](https://packagingindustryreports.com/wp-content/uploads/2019/09/OpenAI-Test-Proves-That-Even-Bots-Can-Cheat-During-Hide-And-Seek-675x450.jpg)](https://openai.com/blog/emergent-tool-use/)
#
# Fuente:
# [OpenAI Test Proves That Even Bots Can Cheat During Hide-And-Seek](https://packagingindustryreports.com/wp-content/uploads/2019/09/OpenAI-Test-Proves-That-Even-Bots-Can-Cheat-During-Hide-And-Seek-675x450.jpg)

# %% [markdown]
# ## Últimas Noticias de Inteligencia Artificial

# %% [markdown]
# ¿Es esta bella reunión de cables y sensores inteligencia artificial?
#
# [![Sophia](https://cdn.expatwoman.com/s3fs-public/soiphia-main.jpg)](https://www.youtube.com/watch?v=CIz1uaAamLs)
#
# Fuente: [Dot CSV](https://www.youtube.com/watch?v=CIz1uaAamLs)
